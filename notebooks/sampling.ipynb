# %%
# Importing libraries and ignoring warnings

import warnings
import pandas as pd
import pickle
import sys

sys.path.append('..')
warnings.filterwarnings('ignore')

# %%
from scripts.data_transformation import DataTransformer

DT = DataTransformer()

# %%
# Reading the train store data

train = pd.read_csv('../data/train_data_clean.csv',index_col='Date')
train.head()
# Out:
#             Store  DayOfWeek    Sales  Customers  Open  Promo StateHoliday  \
# Date
# 2015-07-31      1          5   5263.0      555.0     1      1   No Holiday
# 2015-07-31      2          5   6064.0      625.0     1      1   No Holiday
# 2015-07-31      3          5   8314.0      821.0     1      1   No Holiday
# 2015-07-31      4          5  13995.0      596.0     1      1   No Holiday
# 2015-07-31      5          5   4822.0      559.0     1      1   No Holiday
#
#             SchoolHoliday StoreType Assortment  ...  \
# Date                                            ...
# 2015-07-31              1         c          a  ...
# 2015-07-31              1         a          a  ...
# 2015-07-31              1         a          a  ...
# 2015-07-31              1         c          c  ...
# 2015-07-31              1         a          a  ...
#
#             CompetitionOpenSinceMonth CompetitionOpenSinceYear Promo2  \
# Date
# ...

# %%
# Sampling the train store data

train_sample = train.sample(n=50000) # Taking the 50000 samples

# %%
# Saving it as a csv for display

train_sample.to_csv('../data/train_display.csv',index=False)
