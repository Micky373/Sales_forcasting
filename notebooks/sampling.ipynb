# %%
# Importing libraries and ignoring warnings

import warnings
import pandas as pd

warnings.filterwarnings('ignore')

# %%
# Reading the train store data

train = pd.read_csv('../data/train_store.csv')
train.head()
# Out:
#    Store  DayOfWeek        Date    Sales  Customers  Open  Promo StateHoliday  \
# 0      1          5  2015-07-31   5263.0      555.0     1      1            0
# 1      2          5  2015-07-31   6064.0      625.0     1      1            0
# 2      3          5  2015-07-31   8314.0      821.0     1      1            0
# 3      4          5  2015-07-31  13995.0      596.0     1      1            0
# 4      5          5  2015-07-31   4822.0      559.0     1      1            0
#
#    SchoolHoliday StoreType Assortment  CompetitionDistance  \
# 0              1         c          a               1270.0
# 1              1         a          a                570.0
# 2              1         a          a              14130.0
# 3              1         c          c                620.0
# 4              1         a          a              29910.0
#
#   CompetitionOpenSinceMonth CompetitionOpenSinceYear  Promo2 Promo2SinceWeek  \
# ...

# %%
# Sampling the train store data

train_sample = train.sample(n=50000) # Taking the 50000 samples

# %%
# Saving it as a csv for display

train_sample.to_csv('../apps/train_display.csv',index=False)
